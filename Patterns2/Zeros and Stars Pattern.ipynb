# %%
## Read input as specified in the question.
## Print output as specified in the question.
n = int(input())
i = 1
k = 2*n + 2
while i <=n:
    j = 1   
        #printing first half
    while j<=n:
        if j == i:
            print('*', end='')
        else:
            print(0, end='')
               
        j = j + 1
        #printing * at the middle half
    if j == n+1:
        print('*', end='')
        j = j + 1
            
    while j<=2*n+1:
        if k-j == i:
            print('*', end='')
        else:
            print(0, end= '')
        j = j+1    
    print()
    i = i +1
            
#Alternative apporach
## Read input as specified in the question.
## Print output as specified in the question.

# n = int(input())
# i = 1
# k = 2*n + 2
# while i <=n:
#     j = 1   
#         #printing first half
#     while j<=n:
#         if j == i:
#             print('*', end='')
#         else:
#             print(0, end='')
               
#         j = j + 1
#         #printing * at the middle half
#     if j == n+1:
#         print('*', end='')
#         j = j + 1

#     j = j- n - 1

#     while j<=n:
#         if i == n-j+1:
#             print('*', end='')
#         else:
#             print(0, end= '')
#         j = j+1    
#     print()
#     i = i +1

# %%
"""
Sample Input 1 :
3
Sample Output 1 :
*00*00*
0*0*0*0
00***00
Sample Input 2 :
5
Sample Output 2 :
*0000*0000*
0*000*000*0
00*00*00*00
000*0*0*000
0000***0000
"""
